# %%
from bs4 import BeautifulSoup
import requests as re
import pandas as pd
import numpy as np
import os

# %%
pd.set_option('display.max_colwidth', -1)

# %%
# %%time
col = ['year', 'month', 'url']
top_df = pd.DataFrame(columns=col)
#url = input("http://www.e-stat.go.jp/SG1/estat/OtherListE.do?bid=000001006005&cycode=1")
url = "http://www.e-stat.go.jp/SG1/estat/OtherListE.do?bid=000001006005&cycode=1"
path='https://www.e-stat.go.jp'
r = re.get(url)
data = r.text
year='None'
soup = BeautifulSoup(data, "lxml")
table = soup.find('div', {'class': 'stat-cycle_sheet'})
for year_section in table.find_all('ul', {'class': 'stat-cycle_ul_other'}):
    header = year_section.find('li', {'class': 'stat-cycle_header'})
    year = header.find('span').get_text(' ', strip=True)
    #   print('year changed to ' + year)
    months_section = year_section.find('li', {'class': 'stat-cycle_item'})
    for month_row in months_section.find_all('div'):
        month_a = month_row.find('a')
        month = month_a.get_text().rstrip('.\n')
        monthurl = path + month_a.get('href')
        row = pd.DataFrame([[year, month, monthurl]], columns=col)
        if(len(top_df)==0):
            top_df = row
        else:
            top_df = top_df.append(row, ignore_index=True) #why the hell doesn't df.append work inplace?? Didn't it always use to?
print(top_df)
# Out:
#      year month  \
# 0    2018  Jan
# 1    2018  Feb
# 2    2018  Mar
# 3    2018  Apr
# 4    2018  May
# 5    2018  Jun
# 6    2017  Jan
# 7    2017  Feb
# 8    2017  Mar
# 9    2017  Apr
# 10   2017  May
# 11   2017  Jun
# 12   2017  Jul
# 13   2017  Aug
# 14   2017  Sep
# 15   2017  Oct
# 16   2017  Nov
# 17   2017  Dec
# 18   2016  Jan
# 19   2016  Feb
# 20   2016  Mar
# 21   2016  Apr
# 22   2016  May
# 23   2016  Jun
# 24   2016  Jul
# 25   2016  Aug
# 26   2016  Sep
# 27   2016  Oct
# 28   2016  Nov
# 29   2016  Dec
# ..    ...  ...
# 120  2008  Jul
# 121  2008  Aug
# 122  2008  Sep
# 123  2008  Oct
# 124  2008  Nov
# 125  2008  Dec
# 126  2007  Jan
# 127  2007  Feb
# 128  2007  Mar
# 129  2007  Apr
# 130  2007  May
# 131  2007  Jun
# 132  2007  Jul
# 133  2007  Aug
# 134  2007  Sep
# 135  2007  Oct
# 136  2007  Nov
# 137  2007  Dec
# 138  2006  Jan
# 139  2006  Feb
# 140  2006  Mar
# 141  2006  Apr
# 142  2006  May
# 143  2006  Jun
# 144  2006  Jul
# 145  2006  Aug
# 146  2006  Sep
# 147  2006  Oct
# 148  2006  Nov
# 149  2006  Dec
#
#                                                                                                                                                                        url
# 0    https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20180&month=11010301&result_back=1
# 1    https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20180&month=11010302&result_back=1
# 2    https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20180&month=11010303&result_back=1
# 3    https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20180&month=12040604&result_back=1
# 4    https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20180&month=12040605&result_back=1
# 5    https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20180&month=12040606&result_back=1
# 6    https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20170&month=11010301&result_back=1
# 7    https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20170&month=11010302&result_back=1
# 8    https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20170&month=11010303&result_back=1
# 9    https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20170&month=12040604&result_back=1
# 10   https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20170&month=12040605&result_back=1
# 11   https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20170&month=12040606&result_back=1
# 12   https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20170&month=23070907&result_back=1
# 13   https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20170&month=23070908&result_back=1
# 14   https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20170&month=23070909&result_back=1
# 15   https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20170&month=24101210&result_back=1
# 16   https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20170&month=24101211&result_back=1
# 17   https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20170&month=24101212&result_back=1
# 18   https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20160&month=11010301&result_back=1
# 19   https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20160&month=11010302&result_back=1
# 20   https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20160&month=11010303&result_back=1
# 21   https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20160&month=12040604&result_back=1
# 22   https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20160&month=12040605&result_back=1
# 23   https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20160&month=12040606&result_back=1
# 24   https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20160&month=23070907&result_back=1
# 25   https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20160&month=23070908&result_back=1
# 26   https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20160&month=23070909&result_back=1
# 27   https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20160&month=24101210&result_back=1
# 28   https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20160&month=24101211&result_back=1
# 29   https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20160&month=24101212&result_back=1
# ..                                                                                                                                                                     ...
# 120  https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20080&month=23070907&result_back=1
# 121  https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20080&month=23070908&result_back=1
# 122  https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20080&month=23070909&result_back=1
# 123  https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20080&month=24101210&result_back=1
# 124  https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20080&month=24101211&result_back=1
# 125  https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20080&month=24101212&result_back=1
# 126  https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20070&month=11010301&result_back=1
# 127  https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20070&month=11010302&result_back=1
# 128  https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20070&month=11010303&result_back=1
# 129  https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20070&month=12040604&result_back=1
# 130  https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20070&month=12040605&result_back=1
# 131  https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20070&month=12040606&result_back=1
# 132  https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20070&month=23070907&result_back=1
# 133  https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20070&month=23070908&result_back=1
# 134  https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20070&month=23070909&result_back=1
# 135  https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20070&month=24101210&result_back=1
# 136  https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20070&month=24101211&result_back=1
# 137  https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20070&month=24101212&result_back=1
# 138  https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20060&month=11010301&result_back=1
# 139  https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20060&month=11010302&result_back=1
# 140  https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20060&month=11010303&result_back=1
# 141  https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20060&month=12040604&result_back=1
# 142  https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20060&month=12040605&result_back=1
# 143  https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20060&month=12040606&result_back=1
# 144  https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20060&month=23070907&result_back=1
# 145  https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20060&month=23070908&result_back=1
# 146  https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20060&month=23070909&result_back=1
# 147  https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20060&month=24101210&result_back=1
# 148  https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20060&month=24101211&result_back=1
# 149  https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20060&month=24101212&result_back=1
#
# [150 rows x 3 columns]
# Wall time: 2.52 s

# %% [markdown]
# Retrieve available months by parsing website

# %%
def retrieve_month_excels(murl, path):
    print(murl)
    mcols = ['url', 'excel_num', 'excel_description', 'excel_url']
    mdf = pd.DataFrame(columns=mcols)
    mr = re.get(murl)
    mdata = mr.text
    msoup = BeautifulSoup(mdata, "lxml")
    mtable = msoup.find('div', {'class': 'stat-dataset_list-body'})
    for row in mtable.find_all('article', {'class': 'stat-dataset_list-item'}):
        excel_num = row.find('li', {'class': 'stat-dataset_list-detail-item stat-dataset_list-border-top'}).contents[0].replace('\n','')
        excel_description = row.find('a').contents[0]
        excel_url = ''
        excel_a = row.find_all('a')[1]
        
        if(excel_a['data-file_type'] == 'EXCEL'):
            excel_url = path + excel_a['href']
        mdfrow = pd.DataFrame([[murl, excel_num, excel_description, excel_url]], columns=mcols)
        if(len(mdf)==0):
            mdf = mdfrow
        else:
            mdf = mdf.append(mdfrow, ignore_index=True) #why the hell doesn't df.append work inplace?? Didn't it always use to?
    return(mdf)

# %% [markdown]
# Define function to enter link for each month, and store the excel notebook links and descriptions within to a dataframe.

# %%
# %%time
excels_df = pd.concat([retrieve_month_excels(murl, path) for murl in top_df['url']])
excelref_df = top_df.merge(excels_df, how='left', on='url')
# Out:
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20180&month=11010301&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20180&month=11010302&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20180&month=11010303&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20180&month=12040604&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20180&month=12040605&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20180&month=12040606&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20170&month=11010301&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20170&month=11010302&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20170&month=11010303&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20170&month=12040604&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20170&month=12040605&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20170&month=12040606&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20170&month=23070907&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20170&month=23070908&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20170&month=23070909&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20170&month=24101210&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20170&month=24101211&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20170&month=24101212&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20160&month=11010301&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20160&month=11010302&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20160&month=11010303&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20160&month=12040604&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20160&month=12040605&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20160&month=12040606&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20160&month=23070907&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20160&month=23070908&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20160&month=23070909&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20160&month=24101210&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20160&month=24101211&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20160&month=24101212&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20150&month=11010301&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20150&month=11010302&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20150&month=11010303&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20150&month=12040604&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20150&month=12040605&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20150&month=12040606&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20150&month=23070907&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20150&month=23070908&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20150&month=23070909&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20150&month=24101210&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20150&month=24101211&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20150&month=24101212&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20140&month=11010301&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20140&month=11010302&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20140&month=11010303&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20140&month=12040604&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20140&month=12040605&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20140&month=12040606&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20140&month=23070907&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20140&month=23070908&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20140&month=23070909&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20140&month=24101210&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20140&month=24101211&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20140&month=24101212&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20130&month=11010301&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20130&month=11010302&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20130&month=11010303&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20130&month=12040604&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20130&month=12040605&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20130&month=12040606&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20130&month=23070907&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20130&month=23070908&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20130&month=23070909&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20130&month=24101210&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20130&month=24101211&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20130&month=24101212&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20120&month=11010301&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20120&month=11010302&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20120&month=11010303&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20120&month=12040604&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20120&month=12040605&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20120&month=12040606&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20120&month=23070907&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20120&month=23070908&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20120&month=23070909&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20120&month=24101210&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20120&month=24101211&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20120&month=24101212&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20110&month=11010301&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20110&month=11010302&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20110&month=11010303&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20110&month=12040604&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20110&month=12040605&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20110&month=12040606&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20110&month=23070907&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20110&month=23070908&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20110&month=23070909&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20110&month=24101210&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20110&month=24101211&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20110&month=24101212&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20100&month=11010301&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20100&month=11010302&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20100&month=11010303&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20100&month=12040604&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20100&month=12040605&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20100&month=12040606&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20100&month=23070907&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20100&month=23070908&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20100&month=23070909&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20100&month=24101210&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20100&month=24101211&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20100&month=24101212&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20090&month=11010301&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20090&month=11010302&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20090&month=11010303&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20090&month=12040604&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20090&month=12040605&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20090&month=12040606&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20090&month=23070907&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20090&month=23070908&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20090&month=23070909&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20090&month=24101210&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20090&month=24101211&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20090&month=24101212&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20080&month=11010301&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20080&month=11010302&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20080&month=11010303&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20080&month=12040604&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20080&month=12040605&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20080&month=12040606&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20080&month=23070907&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20080&month=23070908&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20080&month=23070909&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20080&month=24101210&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20080&month=24101211&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20080&month=24101212&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20070&month=11010301&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20070&month=11010302&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20070&month=11010303&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20070&month=12040604&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20070&month=12040605&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20070&month=12040606&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20070&month=23070907&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20070&month=23070908&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20070&month=23070909&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20070&month=24101210&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20070&month=24101211&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20070&month=24101212&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20060&month=11010301&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20060&month=11010302&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20060&month=11010303&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20060&month=12040604&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20060&month=12040605&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20060&month=12040606&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20060&month=23070907&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20060&month=23070908&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20060&month=23070909&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20060&month=24101210&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20060&month=24101211&result_back=1
# https://www.e-stat.go.jp/en/stat-search/files?cycle=1&layout=datalist&toukei=00200523&tstat=000000070001&tclass1=000001008739&year=20060&month=24101212&result_back=1
# Wall time: 3min 54s

# %% [markdown]
# Utilize the function retrieve_month_excels to retrieve all available excel sheets for every month in the top-level dataframe

# %%
exceldesccount_df = excelref_df.groupby(['excel_description']).agg(['count']).sort_values([('year', 'count')], ascending=False).iloc[:,:1]
exceldesccount_df.columns=['count']
# exceldesccount_df.insert(0,'excel_description', exceldesccount_df.index)
exceldesccount_df.reset_index(inplace=True)
print(exceldesccount_df)
# Out:
#                                                                                                                                                                                                                             excel_description  \
# 0
# Number of In-migrants from Other Prefectures by Age (5-Year Age Group) and Sex for Japan and Prefectures
#
# 1
# Number of Out-migrants to Other Prefectures by Age (5-Year Age Group) and Sex for Japan and Prefectures
#
# 2
# Number of Net-migration by Age (5-Year Age Group) and Sex for Japan and Prefectures (All nationalities and Japanese)
#
# 3
# Number of Inter-prefectural Migrants by Sex and Origin for Prefectures, Tokyo Area, Nagoya Area, Osaka Area and 21 Major Cities (Japanese)
#
# 4
# Number of Net-migration by Age (5-Year Age Group) and Sex for Japan and Prefectures
#
# 5
# Number of Intra-prefectural Migrants, In-migrants from Other Prefectures and Out-migrants to Other Prefectures by Sex for Japan, Prefectures and 21 Major Cities (All nationalities and  Japanese)
#
# 6
# Number of Out-migrants to Other Prefectures by Age (5-Year Age Group) and Sex for Japan and Prefectures (Japanese)
#
# 7
# Number of In-migrants from Other Prefectures by Age (5-Year Age Group) and Sex for Japan and Prefectures (Japanese)
#
# 8
# Number of Inter-prefectural Migrants by Sex and Origin for Prefectures, Tokyo Area, Nagoya Area, Osaka Area and 21 Major Cities
#
# 9
# Number of Inter-prefectural Migrants by Sex and Origin for Prefectures and 18 Major Cities
#
# 10
# Number of Intra-prefectural Migrants, In-migrants from Other Prefectures and Out-migrants to Other Prefectures by Sex for Japan, Prefectures and 18 Major Cities
#
# 11
# Number of Inter-prefectural Migrants by Sex and Origin for Prefectures, Tokyo Area, Nagoya Area, Osaka Area and 20 Major Cities
#
# 12
# Number of Intra-prefectural Migrants, In-migrants from Other Prefectures and Out-migrants to Other Prefectures by Sex for Japan, Prefectures and 20 Major Cities
#
# 13
# Number of Intra-prefectural Migrants, In-migrants from Other Prefectures and Out-migrants to Other Prefectures by Sex for Japan, Prefectures and 21 Major Cities
#
# 14
# Number of Intra-prefectural Migrants, In-migrants from Other Prefectures and Out-migrants to Other Prefectures by Sex for Japan, Prefectures and 21 Major Cities (All nationalities and Japanese)
#
# 15
# Number of Intra-prefectural Migrants, In-migrants from Other Prefectures and Out-migrants to Other Prefectures by Sex for Japan, Prefectures and 19 Major Cities
#
# 16
# Number of Intra-prefectural Migrants, In-migrants from Other Prefectures and Out-migrants to Other Prefectures by Sex for Japan, Prefectures and 16 Major Cities
#
# 17
# Number of Inter-prefectural Migrants by Sex and Origin for Prefectures and 16 Major Cities
#
# 18
# Number of Inter-prefectural Migrants by Sex and Origin for Prefectures and 19 Major Cities
#
# 19
# Number of Intra-prefectural Migrants, In-migrants from Other Prefectures and Out-migrants to Other Prefectures by Sex for Japan, Prefectures, Tokyo Area, Nagoya Area, Osaka Area and 21 Major Cities (All nationalities and  Japanese)
#
# 20
# Number of Net-migration by Age (Five-Year Groups) and Sex for Japan and Prefectures (All nationalities and Japanese)
#
# 21
# Number of In-migrants from Other Prefectures by Age (Five-Year Groups) and Sex for Japan and Prefectures (Japanese)
#
# 22
# Number of Out-migrants to Other Prefectures by Age (Five-Year Groups) and Sex for Japan and Prefectures (Japanese)
#
# 23
# Number of Inter-prefectural Migrants by Sex and Origin for Prefectures, Tokyo Area, Nagoya Area, Osaka Area and 19 Major Cities
#
#
#     count
# 0   55
# 1   55
# 2   54
# 3   47
# 4   42
# 5   41
# 6   41
# 7   41
# 8   28
# 9   27
# 10  27
# 11  24
# 12  24
# 13  15
# 14  13
# 15  12
# 16  12
# 17  12
# 18  9
# 19  6
# 20  6
# 21  6
# 22  6
# 23  3

# %% [markdown]
# Count of sheets of each description in all available data

# %%
# %%time
# print(excelref_df.head())
mdir = os.path.join('extracts', 'monthly_reports')
if not os.path.exists(mdir):
    os.makedirs(mdir)
months = excelref_df.month.unique() #do not sort, retain the order
monthnum = list(range(1,13,1))
monthdirs = [str(num).zfill(2) + month for num,month in zip(monthnum, months)]
monthnamedict = dict(zip(months, monthdirs))
print(monthnamedict)

for index,row in excelref_df.iterrows():
    filedir = os.path.join(mdir, row['year'], monthnamedict.get(row['month']))
    if not os.path.exists(filedir):
        os.makedirs(filedir)
    filename = str(row['excel_num']) + '.xls'
    savepath = os.path.join(filedir, filename)
    if not os.path.isfile(savepath):
        fileresponse = re.get(row['excel_url'], stream=True)
        with open(savepath, 'wb') as out_file:
            out_file.write(fileresponse.content)
        del fileresponse
        print("saved " + savepath)
# Out:
# {'Jan': '01Jan', 'Feb': '02Feb', 'Mar': '03Mar', 'Apr': '04Apr', 'May': '05May', 'Jun': '06Jun', 'Jul': '07Jul', 'Aug': '08Aug', 'Sep': '09Sep', 'Oct': '10Oct', 'Nov': '11Nov', 'Dec': '12Dec'}
# saved extracts\monthly_reports\2018\01Jan\1.xls
# saved extracts\monthly_reports\2018\01Jan\2.xls
# saved extracts\monthly_reports\2018\01Jan\3-1.xls
# saved extracts\monthly_reports\2018\01Jan\3-2.xls
# saved extracts\monthly_reports\2018\01Jan\3-3.xls
# saved extracts\monthly_reports\2018\02Feb\1.xls
# saved extracts\monthly_reports\2018\02Feb\2.xls
# saved extracts\monthly_reports\2018\02Feb\3-1.xls
# saved extracts\monthly_reports\2018\02Feb\3-2.xls
# saved extracts\monthly_reports\2018\02Feb\3-3.xls
# saved extracts\monthly_reports\2018\03Mar\1.xls
# saved extracts\monthly_reports\2018\03Mar\2.xls
# saved extracts\monthly_reports\2018\03Mar\3-1.xls
# saved extracts\monthly_reports\2018\03Mar\3-2.xls
# saved extracts\monthly_reports\2018\03Mar\3-3.xls
# saved extracts\monthly_reports\2018\04Apr\1.xls
# saved extracts\monthly_reports\2018\04Apr\2.xls
# saved extracts\monthly_reports\2018\04Apr\3-1.xls
# saved extracts\monthly_reports\2018\04Apr\3-2.xls
# saved extracts\monthly_reports\2018\04Apr\3-3.xls
# saved extracts\monthly_reports\2018\05May\1.xls
# saved extracts\monthly_reports\2018\05May\2.xls
# saved extracts\monthly_reports\2018\05May\3-1.xls
# saved extracts\monthly_reports\2018\05May\3-2.xls
# saved extracts\monthly_reports\2018\05May\3-3.xls
# saved extracts\monthly_reports\2018\06Jun\1.xls
# saved extracts\monthly_reports\2018\06Jun\2.xls
# saved extracts\monthly_reports\2018\06Jun\3-1.xls
# saved extracts\monthly_reports\2018\06Jun\3-2.xls
# saved extracts\monthly_reports\2018\06Jun\3-3.xls
# saved extracts\monthly_reports\2017\01Jan\1.xls
# saved extracts\monthly_reports\2017\01Jan\2.xls
# saved extracts\monthly_reports\2017\01Jan\3-1.xls
# saved extracts\monthly_reports\2017\01Jan\3-2.xls
# saved extracts\monthly_reports\2017\01Jan\3-3.xls
# saved extracts\monthly_reports\2017\02Feb\1.xls
# saved extracts\monthly_reports\2017\02Feb\2.xls
# saved extracts\monthly_reports\2017\02Feb\3-1.xls
# saved extracts\monthly_reports\2017\02Feb\3-2.xls
# saved extracts\monthly_reports\2017\02Feb\3-3.xls
# saved extracts\monthly_reports\2017\03Mar\1.xls
# saved extracts\monthly_reports\2017\03Mar\2.xls
# saved extracts\monthly_reports\2017\03Mar\3-1.xls
# saved extracts\monthly_reports\2017\03Mar\3-2.xls
# saved extracts\monthly_reports\2017\03Mar\3-3.xls
# saved extracts\monthly_reports\2017\04Apr\1.xls
# saved extracts\monthly_reports\2017\04Apr\2.xls
# saved extracts\monthly_reports\2017\04Apr\3-1.xls
# saved extracts\monthly_reports\2017\04Apr\3-2.xls
# saved extracts\monthly_reports\2017\04Apr\3-3.xls
# saved extracts\monthly_reports\2017\05May\1.xls
# saved extracts\monthly_reports\2017\05May\2.xls
# saved extracts\monthly_reports\2017\05May\3-1.xls
# saved extracts\monthly_reports\2017\05May\3-2.xls
# saved extracts\monthly_reports\2017\05May\3-3.xls
# saved extracts\monthly_reports\2017\06Jun\1.xls
# saved extracts\monthly_reports\2017\06Jun\2.xls
# saved extracts\monthly_reports\2017\06Jun\3-1.xls
# saved extracts\monthly_reports\2017\06Jun\3-2.xls
# saved extracts\monthly_reports\2017\06Jun\3-3.xls
# saved extracts\monthly_reports\2017\07Jul\1.xls
# saved extracts\monthly_reports\2017\07Jul\2.xls
# saved extracts\monthly_reports\2017\07Jul\3-1.xls
# saved extracts\monthly_reports\2017\07Jul\3-2.xls
# saved extracts\monthly_reports\2017\07Jul\3-3.xls
# saved extracts\monthly_reports\2017\08Aug\1.xls
# saved extracts\monthly_reports\2017\08Aug\2.xls
# saved extracts\monthly_reports\2017\08Aug\3-1.xls
# saved extracts\monthly_reports\2017\08Aug\3-2.xls
# saved extracts\monthly_reports\2017\08Aug\3-3.xls
# saved extracts\monthly_reports\2017\09Sep\1.xls
# saved extracts\monthly_reports\2017\09Sep\2.xls
# saved extracts\monthly_reports\2017\09Sep\3-1.xls
# saved extracts\monthly_reports\2017\09Sep\3-2.xls
# saved extracts\monthly_reports\2017\09Sep\3-3.xls
# saved extracts\monthly_reports\2017\10Oct\1.xls
# saved extracts\monthly_reports\2017\10Oct\2.xls
# saved extracts\monthly_reports\2017\10Oct\3-1.xls
# saved extracts\monthly_reports\2017\10Oct\3-2.xls
# saved extracts\monthly_reports\2017\10Oct\3-3.xls
# saved extracts\monthly_reports\2017\11Nov\1.xls
# saved extracts\monthly_reports\2017\11Nov\2.xls
# saved extracts\monthly_reports\2017\11Nov\3-1.xls
# saved extracts\monthly_reports\2017\11Nov\3-2.xls
# saved extracts\monthly_reports\2017\11Nov\3-3.xls
# saved extracts\monthly_reports\2017\12Dec\1.xls
# saved extracts\monthly_reports\2017\12Dec\2.xls
# saved extracts\monthly_reports\2017\12Dec\3-1.xls
# saved extracts\monthly_reports\2017\12Dec\3-2.xls
# saved extracts\monthly_reports\2017\12Dec\3-3.xls
# saved extracts\monthly_reports\2016\01Jan\1.xls
# saved extracts\monthly_reports\2016\01Jan\2.xls
# saved extracts\monthly_reports\2016\01Jan\3-1.xls
# saved extracts\monthly_reports\2016\01Jan\3-2.xls
# saved extracts\monthly_reports\2016\01Jan\3-3.xls
# saved extracts\monthly_reports\2016\02Feb\1.xls
# saved extracts\monthly_reports\2016\02Feb\2.xls
# saved extracts\monthly_reports\2016\02Feb\3-1.xls
# saved extracts\monthly_reports\2016\02Feb\3-2.xls
# saved extracts\monthly_reports\2016\02Feb\3-3.xls
# saved extracts\monthly_reports\2016\03Mar\1.xls
# saved extracts\monthly_reports\2016\03Mar\2.xls
# saved extracts\monthly_reports\2016\03Mar\3-1.xls
# saved extracts\monthly_reports\2016\03Mar\3-2.xls
# saved extracts\monthly_reports\2016\03Mar\3-3.xls
# saved extracts\monthly_reports\2016\04Apr\1.xls
# saved extracts\monthly_reports\2016\04Apr\2.xls
# saved extracts\monthly_reports\2016\04Apr\3-1.xls
# saved extracts\monthly_reports\2016\04Apr\3-2.xls
# saved extracts\monthly_reports\2016\04Apr\3-3.xls
# saved extracts\monthly_reports\2016\05May\1.xls
# saved extracts\monthly_reports\2016\05May\2.xls
# saved extracts\monthly_reports\2016\05May\3-1.xls
# saved extracts\monthly_reports\2016\05May\3-2.xls
# saved extracts\monthly_reports\2016\05May\3-3.xls
# saved extracts\monthly_reports\2016\06Jun\1.xls
# saved extracts\monthly_reports\2016\06Jun\2.xls
# saved extracts\monthly_reports\2016\06Jun\3-1.xls
# saved extracts\monthly_reports\2016\06Jun\3-2.xls
# saved extracts\monthly_reports\2016\06Jun\3-3.xls
# saved extracts\monthly_reports\2016\07Jul\1.xls
# saved extracts\monthly_reports\2016\07Jul\2.xls
# saved extracts\monthly_reports\2016\07Jul\3-1.xls
# saved extracts\monthly_reports\2016\07Jul\3-2.xls
# saved extracts\monthly_reports\2016\07Jul\3-3.xls
# saved extracts\monthly_reports\2016\08Aug\1.xls
# saved extracts\monthly_reports\2016\08Aug\2.xls
# saved extracts\monthly_reports\2016\08Aug\3-1.xls
# saved extracts\monthly_reports\2016\08Aug\3-2.xls
# saved extracts\monthly_reports\2016\08Aug\3-3.xls
# saved extracts\monthly_reports\2016\09Sep\1.xls
# saved extracts\monthly_reports\2016\09Sep\2.xls
# saved extracts\monthly_reports\2016\09Sep\3-1.xls
# saved extracts\monthly_reports\2016\09Sep\3-2.xls
# saved extracts\monthly_reports\2016\09Sep\3-3.xls
# saved extracts\monthly_reports\2016\10Oct\1.xls
# saved extracts\monthly_reports\2016\10Oct\2.xls
# saved extracts\monthly_reports\2016\10Oct\3-1.xls
# saved extracts\monthly_reports\2016\10Oct\3-2.xls
# saved extracts\monthly_reports\2016\10Oct\3-3.xls
# saved extracts\monthly_reports\2016\11Nov\1.xls
# saved extracts\monthly_reports\2016\11Nov\2.xls
# saved extracts\monthly_reports\2016\11Nov\3-1.xls
# saved extracts\monthly_reports\2016\11Nov\3-2.xls
# saved extracts\monthly_reports\2016\11Nov\3-3.xls
# saved extracts\monthly_reports\2016\12Dec\1.xls
# saved extracts\monthly_reports\2016\12Dec\2.xls
# saved extracts\monthly_reports\2016\12Dec\3-1.xls
# saved extracts\monthly_reports\2016\12Dec\3-2.xls
# saved extracts\monthly_reports\2016\12Dec\3-3.xls
# saved extracts\monthly_reports\2015\01Jan\1.xls
# saved extracts\monthly_reports\2015\01Jan\2.xls
# saved extracts\monthly_reports\2015\01Jan\3-1.xls
# saved extracts\monthly_reports\2015\01Jan\3-2.xls
# saved extracts\monthly_reports\2015\01Jan\3-3.xls
# saved extracts\monthly_reports\2015\02Feb\1.xls
# saved extracts\monthly_reports\2015\02Feb\2.xls
# saved extracts\monthly_reports\2015\02Feb\3-1.xls
# saved extracts\monthly_reports\2015\02Feb\3-2.xls
# saved extracts\monthly_reports\2015\02Feb\3-3.xls
# saved extracts\monthly_reports\2015\03Mar\1.xls
# saved extracts\monthly_reports\2015\03Mar\2.xls
# saved extracts\monthly_reports\2015\03Mar\3-1.xls
# saved extracts\monthly_reports\2015\03Mar\3-2.xls
# saved extracts\monthly_reports\2015\03Mar\3-3.xls
# saved extracts\monthly_reports\2015\04Apr\1.xls
# saved extracts\monthly_reports\2015\04Apr\2.xls
# saved extracts\monthly_reports\2015\04Apr\3-1.xls
# saved extracts\monthly_reports\2015\04Apr\3-2.xls
# saved extracts\monthly_reports\2015\04Apr\3-3.xls
# saved extracts\monthly_reports\2015\05May\1.xls
# saved extracts\monthly_reports\2015\05May\2.xls
# saved extracts\monthly_reports\2015\05May\3-1.xls
# saved extracts\monthly_reports\2015\05May\3-2.xls
# saved extracts\monthly_reports\2015\05May\3-3.xls
# saved extracts\monthly_reports\2015\06Jun\1.xls
# saved extracts\monthly_reports\2015\06Jun\2.xls
# saved extracts\monthly_reports\2015\06Jun\3-1.xls
# saved extracts\monthly_reports\2015\06Jun\3-2.xls
# saved extracts\monthly_reports\2015\06Jun\3-3.xls
# saved extracts\monthly_reports\2015\07Jul\1.xls
# saved extracts\monthly_reports\2015\07Jul\2.xls
# saved extracts\monthly_reports\2015\07Jul\3-1.xls
# saved extracts\monthly_reports\2015\07Jul\3-2.xls
# saved extracts\monthly_reports\2015\07Jul\3-3.xls
# saved extracts\monthly_reports\2015\08Aug\1.xls
# saved extracts\monthly_reports\2015\08Aug\2.xls
# saved extracts\monthly_reports\2015\08Aug\3-1.xls
# saved extracts\monthly_reports\2015\08Aug\3-2.xls
# saved extracts\monthly_reports\2015\08Aug\3-3.xls
# saved extracts\monthly_reports\2015\09Sep\1.xls
# saved extracts\monthly_reports\2015\09Sep\2.xls
# saved extracts\monthly_reports\2015\09Sep\3-1.xls
# saved extracts\monthly_reports\2015\09Sep\3-2.xls
# saved extracts\monthly_reports\2015\09Sep\3-3.xls
# saved extracts\monthly_reports\2015\10Oct\1.xls
# saved extracts\monthly_reports\2015\10Oct\2.xls
# saved extracts\monthly_reports\2015\10Oct\3-1.xls
# saved extracts\monthly_reports\2015\10Oct\3-2.xls
# saved extracts\monthly_reports\2015\10Oct\3-3.xls
# saved extracts\monthly_reports\2015\11Nov\1.xls
# saved extracts\monthly_reports\2015\11Nov\2.xls
# saved extracts\monthly_reports\2015\11Nov\3-1.xls
# saved extracts\monthly_reports\2015\11Nov\3-2.xls
# saved extracts\monthly_reports\2015\11Nov\3-3.xls
# saved extracts\monthly_reports\2015\12Dec\1.xls
# saved extracts\monthly_reports\2015\12Dec\2.xls
# saved extracts\monthly_reports\2015\12Dec\3-1.xls
# saved extracts\monthly_reports\2015\12Dec\3-2.xls
# saved extracts\monthly_reports\2015\12Dec\3-3.xls
# saved extracts\monthly_reports\2014\01Jan\1.xls
# saved extracts\monthly_reports\2014\01Jan\2.xls
# saved extracts\monthly_reports\2014\01Jan\3-1.xls
# saved extracts\monthly_reports\2014\01Jan\3-2.xls
# saved extracts\monthly_reports\2014\01Jan\3-3.xls
# saved extracts\monthly_reports\2014\02Feb\1.xls
# saved extracts\monthly_reports\2014\02Feb\2.xls
# saved extracts\monthly_reports\2014\02Feb\3-1.xls
# saved extracts\monthly_reports\2014\02Feb\3-2.xls
# saved extracts\monthly_reports\2014\02Feb\3-3.xls
# saved extracts\monthly_reports\2014\03Mar\1.xls
# saved extracts\monthly_reports\2014\03Mar\2.xls
# saved extracts\monthly_reports\2014\03Mar\3-1.xls
# saved extracts\monthly_reports\2014\03Mar\3-2.xls
# saved extracts\monthly_reports\2014\03Mar\3-3.xls
# saved extracts\monthly_reports\2014\04Apr\1.xls
# saved extracts\monthly_reports\2014\04Apr\2.xls
# saved extracts\monthly_reports\2014\04Apr\3-1.xls
# saved extracts\monthly_reports\2014\04Apr\3-2.xls
# saved extracts\monthly_reports\2014\04Apr\3-3.xls
# saved extracts\monthly_reports\2014\05May\1.xls
# saved extracts\monthly_reports\2014\05May\2.xls
# saved extracts\monthly_reports\2014\05May\3-1.xls
# saved extracts\monthly_reports\2014\05May\3-2.xls
# saved extracts\monthly_reports\2014\05May\3-3.xls
# saved extracts\monthly_reports\2014\06Jun\1.xls
# saved extracts\monthly_reports\2014\06Jun\2.xls
# saved extracts\monthly_reports\2014\06Jun\3-1.xls
# saved extracts\monthly_reports\2014\06Jun\3-2.xls
# saved extracts\monthly_reports\2014\06Jun\3-3.xls
# saved extracts\monthly_reports\2014\07Jul\1.xls
# saved extracts\monthly_reports\2014\07Jul\2.xls
# saved extracts\monthly_reports\2014\07Jul\3-1.xls
# saved extracts\monthly_reports\2014\07Jul\3-2.xls
# saved extracts\monthly_reports\2014\07Jul\3-3.xls
# saved extracts\monthly_reports\2014\08Aug\1.xls
# saved extracts\monthly_reports\2014\08Aug\2.xls
# saved extracts\monthly_reports\2014\08Aug\3-1.xls
# saved extracts\monthly_reports\2014\08Aug\3-2.xls
# saved extracts\monthly_reports\2014\08Aug\3-3.xls
# saved extracts\monthly_reports\2014\09Sep\1.xls
# saved extracts\monthly_reports\2014\09Sep\2.xls
# saved extracts\monthly_reports\2014\09Sep\3-1.xls
# saved extracts\monthly_reports\2014\09Sep\3-2.xls
# saved extracts\monthly_reports\2014\09Sep\3-3.xls
# saved extracts\monthly_reports\2014\10Oct\1.xls
# saved extracts\monthly_reports\2014\10Oct\2.xls
# saved extracts\monthly_reports\2014\10Oct\3-1.xls
# saved extracts\monthly_reports\2014\10Oct\3-2.xls
# saved extracts\monthly_reports\2014\10Oct\3-3.xls
# saved extracts\monthly_reports\2014\11Nov\1.xls
# saved extracts\monthly_reports\2014\11Nov\2.xls
# saved extracts\monthly_reports\2014\11Nov\3-1.xls
# saved extracts\monthly_reports\2014\11Nov\3-2.xls
# saved extracts\monthly_reports\2014\11Nov\3-3.xls
# saved extracts\monthly_reports\2014\12Dec\1.xls
# saved extracts\monthly_reports\2014\12Dec\2.xls
# saved extracts\monthly_reports\2014\12Dec\3-1.xls
# saved extracts\monthly_reports\2014\12Dec\3-2.xls
# saved extracts\monthly_reports\2014\12Dec\3-3.xls
# saved extracts\monthly_reports\2013\01Jan\1.xls
# saved extracts\monthly_reports\2013\01Jan\2.xls
# saved extracts\monthly_reports\2013\01Jan\3-1.xls
# saved extracts\monthly_reports\2013\01Jan\3-2.xls
# saved extracts\monthly_reports\2013\01Jan\3-3.xls
# saved extracts\monthly_reports\2013\02Feb\1.xls
# saved extracts\monthly_reports\2013\02Feb\2.xls
# saved extracts\monthly_reports\2013\02Feb\3-1.xls
# saved extracts\monthly_reports\2013\02Feb\3-2.xls
# saved extracts\monthly_reports\2013\02Feb\3-3.xls
# saved extracts\monthly_reports\2013\03Mar\1.xls
# saved extracts\monthly_reports\2013\03Mar\2.xls
# saved extracts\monthly_reports\2013\03Mar\3-1.xls
# saved extracts\monthly_reports\2013\03Mar\3-2.xls
# saved extracts\monthly_reports\2013\03Mar\3-3.xls
# saved extracts\monthly_reports\2013\04Apr\1.xls
# saved extracts\monthly_reports\2013\04Apr\2.xls
# saved extracts\monthly_reports\2013\04Apr\3-1.xls
# saved extracts\monthly_reports\2013\04Apr\3-2.xls
# saved extracts\monthly_reports\2013\04Apr\3-3.xls
# saved extracts\monthly_reports\2013\05May\1.xls
# saved extracts\monthly_reports\2013\05May\2.xls
# saved extracts\monthly_reports\2013\05May\3-1.xls
# saved extracts\monthly_reports\2013\05May\3-2.xls
# saved extracts\monthly_reports\2013\05May\3-3.xls
# saved extracts\monthly_reports\2013\06Jun\1.xls
# saved extracts\monthly_reports\2013\06Jun\2.xls
# saved extracts\monthly_reports\2013\06Jun\3-1.xls
# saved extracts\monthly_reports\2013\06Jun\3-2.xls
# saved extracts\monthly_reports\2013\06Jun\3-3.xls
# saved extracts\monthly_reports\2013\07Jul\1.xls
# saved extracts\monthly_reports\2013\07Jul\2.xls
# saved extracts\monthly_reports\2013\07Jul\3-1.xls
# saved extracts\monthly_reports\2013\07Jul\3-2.xls
# saved extracts\monthly_reports\2013\07Jul\3-3.xls
# saved extracts\monthly_reports\2013\08Aug\1.xls
# saved extracts\monthly_reports\2013\08Aug\2.xls
# saved extracts\monthly_reports\2013\08Aug\3-1.xls
# saved extracts\monthly_reports\2013\08Aug\3-2.xls
# saved extracts\monthly_reports\2013\08Aug\3-3.xls
# saved extracts\monthly_reports\2013\09Sep\1.xls
# saved extracts\monthly_reports\2013\09Sep\2.xls
# saved extracts\monthly_reports\2013\09Sep\3-1.xls
# saved extracts\monthly_reports\2013\09Sep\3-2.xls
# saved extracts\monthly_reports\2013\09Sep\3-3.xls
# saved extracts\monthly_reports\2013\10Oct\1.xls
# saved extracts\monthly_reports\2013\10Oct\2.xls
# saved extracts\monthly_reports\2013\10Oct\3-1.xls
# saved extracts\monthly_reports\2013\10Oct\3-2.xls
# saved extracts\monthly_reports\2013\10Oct\3-3.xls
# saved extracts\monthly_reports\2013\11Nov\1.xls
# saved extracts\monthly_reports\2013\11Nov\2.xls
# saved extracts\monthly_reports\2013\11Nov\3-1.xls
# saved extracts\monthly_reports\2013\11Nov\3-2.xls
# saved extracts\monthly_reports\2013\11Nov\3-3.xls
# saved extracts\monthly_reports\2013\12Dec\1.xls
# saved extracts\monthly_reports\2013\12Dec\2.xls
# saved extracts\monthly_reports\2013\12Dec\3-1.xls
# saved extracts\monthly_reports\2013\12Dec\3-2.xls
# saved extracts\monthly_reports\2013\12Dec\3-3.xls
# saved extracts\monthly_reports\2012\01Jan\1.xls
# saved extracts\monthly_reports\2012\01Jan\2.xls
# saved extracts\monthly_reports\2012\01Jan\3-1.xls
# saved extracts\monthly_reports\2012\01Jan\3-2.xls
# saved extracts\monthly_reports\2012\01Jan\3-3.xls
# saved extracts\monthly_reports\2012\02Feb\1.xls
# saved extracts\monthly_reports\2012\02Feb\2.xls
# saved extracts\monthly_reports\2012\02Feb\3-1.xls
# saved extracts\monthly_reports\2012\02Feb\3-2.xls
# saved extracts\monthly_reports\2012\02Feb\3-3.xls
# saved extracts\monthly_reports\2012\03Mar\1.xls
# saved extracts\monthly_reports\2012\03Mar\2.xls
# saved extracts\monthly_reports\2012\03Mar\3-1.xls
# saved extracts\monthly_reports\2012\03Mar\3-2.xls
# saved extracts\monthly_reports\2012\03Mar\3-3.xls
# saved extracts\monthly_reports\2012\04Apr\1.xls
# saved extracts\monthly_reports\2012\04Apr\2.xls
# saved extracts\monthly_reports\2012\04Apr\3-1.xls
# saved extracts\monthly_reports\2012\04Apr\3-2.xls
# saved extracts\monthly_reports\2012\04Apr\3-3.xls
# saved extracts\monthly_reports\2012\05May\1.xls
# saved extracts\monthly_reports\2012\05May\2.xls
# saved extracts\monthly_reports\2012\05May\3-1.xls
# saved extracts\monthly_reports\2012\05May\3-2.xls
# saved extracts\monthly_reports\2012\05May\3-3.xls
# saved extracts\monthly_reports\2012\06Jun\1.xls
# saved extracts\monthly_reports\2012\06Jun\2.xls
# saved extracts\monthly_reports\2012\06Jun\3-1.xls
# saved extracts\monthly_reports\2012\06Jun\3-2.xls
# saved extracts\monthly_reports\2012\06Jun\3-3.xls
# saved extracts\monthly_reports\2012\07Jul\1.xls
# saved extracts\monthly_reports\2012\07Jul\2.xls
# saved extracts\monthly_reports\2012\07Jul\3-1.xls
# saved extracts\monthly_reports\2012\07Jul\3-2.xls
# saved extracts\monthly_reports\2012\07Jul\3-3.xls
# saved extracts\monthly_reports\2012\08Aug\1.xls
# saved extracts\monthly_reports\2012\08Aug\2.xls
# saved extracts\monthly_reports\2012\08Aug\3-1.xls
# saved extracts\monthly_reports\2012\08Aug\3-2.xls
# saved extracts\monthly_reports\2012\08Aug\3-3.xls
# saved extracts\monthly_reports\2012\09Sep\1.xls
# saved extracts\monthly_reports\2012\09Sep\2.xls
# saved extracts\monthly_reports\2012\09Sep\3-1.xls
# saved extracts\monthly_reports\2012\09Sep\3-2.xls
# saved extracts\monthly_reports\2012\09Sep\3-3.xls
# saved extracts\monthly_reports\2012\10Oct\1.xls
# saved extracts\monthly_reports\2012\10Oct\2.xls
# saved extracts\monthly_reports\2012\10Oct\3-1.xls
# saved extracts\monthly_reports\2012\10Oct\3-2.xls
# saved extracts\monthly_reports\2012\10Oct\3-3.xls
# saved extracts\monthly_reports\2012\11Nov\1.xls
# saved extracts\monthly_reports\2012\11Nov\2.xls
# saved extracts\monthly_reports\2012\11Nov\3-1.xls
# saved extracts\monthly_reports\2012\11Nov\3-2.xls
# saved extracts\monthly_reports\2012\11Nov\3-3.xls
# saved extracts\monthly_reports\2012\12Dec\1.xls
# saved extracts\monthly_reports\2012\12Dec\2.xls
# saved extracts\monthly_reports\2012\12Dec\3-1.xls
# saved extracts\monthly_reports\2012\12Dec\3-2.xls
# saved extracts\monthly_reports\2012\12Dec\3-3.xls
# saved extracts\monthly_reports\2011\01Jan\1.xls
# saved extracts\monthly_reports\2011\01Jan\2.xls
# saved extracts\monthly_reports\2011\01Jan\3-1.xls
# saved extracts\monthly_reports\2011\01Jan\3-2.xls
# saved extracts\monthly_reports\2011\01Jan\3-3.xls
# saved extracts\monthly_reports\2011\02Feb\1.xls
# saved extracts\monthly_reports\2011\02Feb\2.xls
# saved extracts\monthly_reports\2011\02Feb\3-1.xls
# saved extracts\monthly_reports\2011\02Feb\3-2.xls
# saved extracts\monthly_reports\2011\02Feb\3-3.xls
# saved extracts\monthly_reports\2011\03Mar\1.xls
# saved extracts\monthly_reports\2011\03Mar\2.xls
# saved extracts\monthly_reports\2011\03Mar\3-1.xls
# saved extracts\monthly_reports\2011\03Mar\3-2.xls
# saved extracts\monthly_reports\2011\03Mar\3-3.xls
# saved extracts\monthly_reports\2011\04Apr\1.xls
# saved extracts\monthly_reports\2011\04Apr\2.xls
# saved extracts\monthly_reports\2011\04Apr\3-1.xls
# saved extracts\monthly_reports\2011\04Apr\3-2.xls
# saved extracts\monthly_reports\2011\04Apr\3-3.xls
# saved extracts\monthly_reports\2011\05May\1.xls
# saved extracts\monthly_reports\2011\05May\2.xls
# saved extracts\monthly_reports\2011\05May\3-1.xls
# saved extracts\monthly_reports\2011\05May\3-2.xls
# saved extracts\monthly_reports\2011\05May\3-3.xls
# saved extracts\monthly_reports\2011\06Jun\1.xls
# saved extracts\monthly_reports\2011\06Jun\2.xls
# saved extracts\monthly_reports\2011\06Jun\3-1.xls
# saved extracts\monthly_reports\2011\06Jun\3-2.xls
# saved extracts\monthly_reports\2011\06Jun\3-3.xls
# saved extracts\monthly_reports\2011\07Jul\1.xls
# saved extracts\monthly_reports\2011\07Jul\2.xls
# saved extracts\monthly_reports\2011\07Jul\3-1.xls
# saved extracts\monthly_reports\2011\07Jul\3-2.xls
# saved extracts\monthly_reports\2011\07Jul\3-3.xls
# saved extracts\monthly_reports\2011\08Aug\1.xls
# saved extracts\monthly_reports\2011\08Aug\2.xls
# saved extracts\monthly_reports\2011\08Aug\3-1.xls
# saved extracts\monthly_reports\2011\08Aug\3-2.xls
# saved extracts\monthly_reports\2011\08Aug\3-3.xls
# saved extracts\monthly_reports\2011\09Sep\1.xls
# saved extracts\monthly_reports\2011\09Sep\2.xls
# saved extracts\monthly_reports\2011\09Sep\3-1.xls
# saved extracts\monthly_reports\2011\09Sep\3-2.xls
# saved extracts\monthly_reports\2011\09Sep\3-3.xls
# saved extracts\monthly_reports\2011\10Oct\1.xls
# saved extracts\monthly_reports\2011\10Oct\2.xls
# saved extracts\monthly_reports\2011\10Oct\3-1.xls
# saved extracts\monthly_reports\2011\10Oct\3-2.xls
# saved extracts\monthly_reports\2011\10Oct\3-3.xls
# saved extracts\monthly_reports\2011\11Nov\1.xls
# saved extracts\monthly_reports\2011\11Nov\2.xls
# saved extracts\monthly_reports\2011\11Nov\3-1.xls
# saved extracts\monthly_reports\2011\11Nov\3-2.xls
# saved extracts\monthly_reports\2011\11Nov\3-3.xls
# saved extracts\monthly_reports\2011\12Dec\1.xls
# saved extracts\monthly_reports\2011\12Dec\2.xls
# saved extracts\monthly_reports\2011\12Dec\3-1.xls
# saved extracts\monthly_reports\2011\12Dec\3-2.xls
# saved extracts\monthly_reports\2011\12Dec\3-3.xls
# saved extracts\monthly_reports\2010\01Jan\1.xls
# saved extracts\monthly_reports\2010\01Jan\2.xls
# saved extracts\monthly_reports\2010\01Jan\3-1.xls
# saved extracts\monthly_reports\2010\01Jan\3-2.xls
# saved extracts\monthly_reports\2010\01Jan\3-3.xls
# saved extracts\monthly_reports\2010\02Feb\1.xls
# saved extracts\monthly_reports\2010\02Feb\2.xls
# saved extracts\monthly_reports\2010\02Feb\3-1.xls
# saved extracts\monthly_reports\2010\02Feb\3-2.xls
# saved extracts\monthly_reports\2010\02Feb\3-3.xls
# saved extracts\monthly_reports\2010\03Mar\1.xls
# saved extracts\monthly_reports\2010\03Mar\2.xls
# saved extracts\monthly_reports\2010\03Mar\3-1.xls
# saved extracts\monthly_reports\2010\03Mar\3-2.xls
# saved extracts\monthly_reports\2010\03Mar\3-3.xls
# saved extracts\monthly_reports\2010\04Apr\1.xls
# saved extracts\monthly_reports\2010\04Apr\2.xls
# saved extracts\monthly_reports\2010\04Apr\3-1.xls
# saved extracts\monthly_reports\2010\04Apr\3-2.xls
# saved extracts\monthly_reports\2010\04Apr\3-3.xls
# saved extracts\monthly_reports\2010\05May\1.xls
# saved extracts\monthly_reports\2010\05May\2.xls
# saved extracts\monthly_reports\2010\05May\3-1.xls
# saved extracts\monthly_reports\2010\05May\3-2.xls
# saved extracts\monthly_reports\2010\05May\3-3.xls
# saved extracts\monthly_reports\2010\06Jun\1.xls
# saved extracts\monthly_reports\2010\06Jun\2.xls
# saved extracts\monthly_reports\2010\06Jun\3-1.xls
# saved extracts\monthly_reports\2010\06Jun\3-2.xls
# saved extracts\monthly_reports\2010\06Jun\3-3.xls
# saved extracts\monthly_reports\2010\07Jul\1.xls
# saved extracts\monthly_reports\2010\07Jul\2.xls
# saved extracts\monthly_reports\2010\07Jul\3-1.xls
# saved extracts\monthly_reports\2010\07Jul\3-2.xls
# saved extracts\monthly_reports\2010\07Jul\3-3.xls
# saved extracts\monthly_reports\2010\08Aug\1.xls
# saved extracts\monthly_reports\2010\08Aug\2.xls
# saved extracts\monthly_reports\2010\08Aug\3-1.xls
# saved extracts\monthly_reports\2010\08Aug\3-2.xls
# saved extracts\monthly_reports\2010\08Aug\3-3.xls
# saved extracts\monthly_reports\2010\09Sep\1.xls
# saved extracts\monthly_reports\2010\09Sep\2.xls
# saved extracts\monthly_reports\2010\09Sep\3-1.xls
# saved extracts\monthly_reports\2010\09Sep\3-2.xls
# saved extracts\monthly_reports\2010\09Sep\3-3.xls
# saved extracts\monthly_reports\2010\10Oct\1.xls
# saved extracts\monthly_reports\2010\10Oct\2.xls
# saved extracts\monthly_reports\2010\10Oct\3-1.xls
# saved extracts\monthly_reports\2010\10Oct\3-2.xls
# saved extracts\monthly_reports\2010\10Oct\3-3.xls
# saved extracts\monthly_reports\2010\11Nov\1.xls
# saved extracts\monthly_reports\2010\11Nov\2.xls
# saved extracts\monthly_reports\2010\11Nov\3-1.xls
# saved extracts\monthly_reports\2010\11Nov\3-2.xls
# saved extracts\monthly_reports\2010\11Nov\3-3.xls
# saved extracts\monthly_reports\2010\12Dec\1.xls
# saved extracts\monthly_reports\2010\12Dec\2.xls
# saved extracts\monthly_reports\2010\12Dec\3-1.xls
# saved extracts\monthly_reports\2010\12Dec\3-2.xls
# saved extracts\monthly_reports\2010\12Dec\3-3.xls
# saved extracts\monthly_reports\2009\01Jan\1.xls
# saved extracts\monthly_reports\2009\01Jan\2.xls
# saved extracts\monthly_reports\2009\02Feb\1.xls
# saved extracts\monthly_reports\2009\02Feb\2.xls
# saved extracts\monthly_reports\2009\03Mar\1.xls
# saved extracts\monthly_reports\2009\03Mar\2.xls
# saved extracts\monthly_reports\2009\04Apr\1.xls
# saved extracts\monthly_reports\2009\04Apr\2.xls
# saved extracts\monthly_reports\2009\05May\1.xls
# saved extracts\monthly_reports\2009\05May\2.xls
# saved extracts\monthly_reports\2009\06Jun\1.xls
# saved extracts\monthly_reports\2009\06Jun\2.xls
# saved extracts\monthly_reports\2009\07Jul\1.xls
# saved extracts\monthly_reports\2009\07Jul\2.xls
# saved extracts\monthly_reports\2009\08Aug\1.xls
# saved extracts\monthly_reports\2009\08Aug\2.xls
# saved extracts\monthly_reports\2009\09Sep\1.xls
# saved extracts\monthly_reports\2009\09Sep\2.xls
# saved extracts\monthly_reports\2009\10Oct\1.xls
# saved extracts\monthly_reports\2009\10Oct\2.xls
# saved extracts\monthly_reports\2009\11Nov\1.xls
# saved extracts\monthly_reports\2009\11Nov\2.xls
# saved extracts\monthly_reports\2009\12Dec\1.xls
# saved extracts\monthly_reports\2009\12Dec\2.xls
# saved extracts\monthly_reports\2008\01Jan\1.xls
# saved extracts\monthly_reports\2008\01Jan\2.xls
# saved extracts\monthly_reports\2008\02Feb\1.xls
# saved extracts\monthly_reports\2008\02Feb\2.xls
# saved extracts\monthly_reports\2008\03Mar\1.xls
# saved extracts\monthly_reports\2008\03Mar\2.xls
# saved extracts\monthly_reports\2008\04Apr\1.xls
# saved extracts\monthly_reports\2008\04Apr\2.xls
# saved extracts\monthly_reports\2008\05May\1.xls
# saved extracts\monthly_reports\2008\05May\2.xls
# saved extracts\monthly_reports\2008\06Jun\1.xls
# saved extracts\monthly_reports\2008\06Jun\2.xls
# saved extracts\monthly_reports\2008\07Jul\1.xls
# saved extracts\monthly_reports\2008\07Jul\2.xls
# saved extracts\monthly_reports\2008\08Aug\1.xls
# saved extracts\monthly_reports\2008\08Aug\2.xls
# saved extracts\monthly_reports\2008\09Sep\1.xls
# saved extracts\monthly_reports\2008\09Sep\2.xls
# saved extracts\monthly_reports\2008\10Oct\1.xls
# saved extracts\monthly_reports\2008\10Oct\2.xls
# saved extracts\monthly_reports\2008\11Nov\1.xls
# saved extracts\monthly_reports\2008\11Nov\2.xls
# saved extracts\monthly_reports\2008\12Dec\1.xls
# saved extracts\monthly_reports\2008\12Dec\2.xls
# saved extracts\monthly_reports\2007\01Jan\1.xls
# saved extracts\monthly_reports\2007\01Jan\2.xls
# saved extracts\monthly_reports\2007\02Feb\1.xls
# saved extracts\monthly_reports\2007\02Feb\2.xls
# saved extracts\monthly_reports\2007\03Mar\1.xls
# saved extracts\monthly_reports\2007\03Mar\2.xls
# saved extracts\monthly_reports\2007\04Apr\1.xls
# saved extracts\monthly_reports\2007\04Apr\2.xls
# saved extracts\monthly_reports\2007\05May\1.xls
# saved extracts\monthly_reports\2007\05May\2.xls
# saved extracts\monthly_reports\2007\06Jun\1.xls
# saved extracts\monthly_reports\2007\06Jun\2.xls
# saved extracts\monthly_reports\2007\07Jul\1.xls
# saved extracts\monthly_reports\2007\07Jul\2.xls
# saved extracts\monthly_reports\2007\08Aug\1.xls
# saved extracts\monthly_reports\2007\08Aug\2.xls
# saved extracts\monthly_reports\2007\09Sep\1.xls
# saved extracts\monthly_reports\2007\09Sep\2.xls
# saved extracts\monthly_reports\2007\10Oct\1.xls
# saved extracts\monthly_reports\2007\10Oct\2.xls
# saved extracts\monthly_reports\2007\11Nov\1.xls
# saved extracts\monthly_reports\2007\11Nov\2.xls
# saved extracts\monthly_reports\2007\12Dec\1.xls
# saved extracts\monthly_reports\2007\12Dec\2.xls
# saved extracts\monthly_reports\2006\01Jan\1.xls
# saved extracts\monthly_reports\2006\01Jan\2.xls
# saved extracts\monthly_reports\2006\02Feb\1.xls
# saved extracts\monthly_reports\2006\02Feb\2.xls
# saved extracts\monthly_reports\2006\03Mar\1.xls
# saved extracts\monthly_reports\2006\03Mar\2.xls
# saved extracts\monthly_reports\2006\04Apr\1.xls
# saved extracts\monthly_reports\2006\04Apr\2.xls
# saved extracts\monthly_reports\2006\05May\1.xls
# saved extracts\monthly_reports\2006\05May\2.xls
# saved extracts\monthly_reports\2006\06Jun\1.xls
# saved extracts\monthly_reports\2006\06Jun\2.xls
# saved extracts\monthly_reports\2006\07Jul\1.xls
# saved extracts\monthly_reports\2006\07Jul\2.xls
# saved extracts\monthly_reports\2006\08Aug\1.xls
# saved extracts\monthly_reports\2006\08Aug\2.xls
# saved extracts\monthly_reports\2006\09Sep\1.xls
# saved extracts\monthly_reports\2006\09Sep\2.xls
# saved extracts\monthly_reports\2006\10Oct\1.xls
# saved extracts\monthly_reports\2006\10Oct\2.xls
# saved extracts\monthly_reports\2006\11Nov\1.xls
# saved extracts\monthly_reports\2006\11Nov\2.xls
# saved extracts\monthly_reports\2006\12Dec\1.xls
# saved extracts\monthly_reports\2006\12Dec\2.xls
# Wall time: 7min 42s

# %% [markdown]
# Save all files available to disk if they don't already exist

# %%
samplecols = ['sampleyear', 'samplemonth', 'sampleexcel_num', 'excel_description', 'count']
samplebydesc_df = pd.DataFrame(columns=samplecols)
samplebydesc_df['excel_description'] = exceldesccount_df['excel_description']
samplebydesc_df['count'] = exceldesccount_df['count']

# %% [markdown]
# I want to build a dataframe of example excel workbooks of each description, so that i can formulate a way to parse each workbook according to their description.

# %%
# sampledesc = 'Number of In-migrants from Other Prefectures by Age (5-Year Age Group) and Sex for Japan and Prefectures'
# dfdf1 = excelref_df[excelref_df['excel_description'] == sampledesc][:1]['month'].iloc[0]
samplebydesc_df['sampleyear'] = [excelref_df[excelref_df['excel_description'] == x][:1]['year'].iloc[0]\
                                 for x in samplebydesc_df['excel_description']]
samplebydesc_df['samplemonth'] = [excelref_df[excelref_df['excel_description'] == x][:1]['month'].iloc[0]\
                                 for x in samplebydesc_df['excel_description']]
samplebydesc_df['sampleexcel_num'] = [excelref_df[excelref_df['excel_description'] == x][:1]['excel_num'].iloc[0]\
                                 for x in samplebydesc_df['excel_description']]
print(samplebydesc_df[:20])
# Out:
#    sampleyear samplemonth sampleexcel_num  \
# 0   2014       Jan         3-1
# 1   2014       Jan         3-2
# 2   2017       Jan         3-3
# 3   2018       Jan         2
# 4   2013       Jan         3-3
# 5   2017       Jan         1
# 6   2017       Jan         3-2
# 7   2017       Jan         3-1
# 8   2014       Jan         2
# 9   2009       Jan         2
# 10  2009       Jan         1
# 11  2012       Jan         2
# 12  2012       Jan         1
# 13  2013       Jan         1
# 14  2014       Jan         1
# 15  2010       Jan         1
# 16  2006       Jan         1
# 17  2006       Jan         2
# 18  2009       Apr         2
# 19  2018       Jan         1
#
#                                                                                                                                                                                                                             excel_description  \
# 0
# Number of In-migrants from Other Prefectures by Age (5-Year Age Group) and Sex for Japan and Prefectures
#
# 1
# Number of Out-migrants to Other Prefectures by Age (5-Year Age Group) and Sex for Japan and Prefectures
#
# 2
# Number of Net-migration by Age (5-Year Age Group) and Sex for Japan and Prefectures (All nationalities and Japanese)
#
# 3
# Number of Inter-prefectural Migrants by Sex and Origin for Prefectures, Tokyo Area, Nagoya Area, Osaka Area and 21 Major Cities (Japanese)
#
# 4
# Number of Net-migration by Age (5-Year Age Group) and Sex for Japan and Prefectures
#
# 5
# Number of Intra-prefectural Migrants, In-migrants from Other Prefectures and Out-migrants to Other Prefectures by Sex for Japan, Prefectures and 21 Major Cities (All nationalities and  Japanese)
#
# 6
# Number of Out-migrants to Other Prefectures by Age (5-Year Age Group) and Sex for Japan and Prefectures (Japanese)
#
# 7
# Number of In-migrants from Other Prefectures by Age (5-Year Age Group) and Sex for Japan and Prefectures (Japanese)
#
# 8
# Number of Inter-prefectural Migrants by Sex and Origin for Prefectures, Tokyo Area, Nagoya Area, Osaka Area and 21 Major Cities
#
# 9
# Number of Inter-prefectural Migrants by Sex and Origin for Prefectures and 18 Major Cities
#
# 10
# Number of Intra-prefectural Migrants, In-migrants from Other Prefectures and Out-migrants to Other Prefectures by Sex for Japan, Prefectures and 18 Major Cities
#
# 11
# Number of Inter-prefectural Migrants by Sex and Origin for Prefectures, Tokyo Area, Nagoya Area, Osaka Area and 20 Major Cities
#
# 12
# Number of Intra-prefectural Migrants, In-migrants from Other Prefectures and Out-migrants to Other Prefectures by Sex for Japan, Prefectures and 20 Major Cities
#
# 13
# Number of Intra-prefectural Migrants, In-migrants from Other Prefectures and Out-migrants to Other Prefectures by Sex for Japan, Prefectures and 21 Major Cities
#
# 14
# Number of Intra-prefectural Migrants, In-migrants from Other Prefectures and Out-migrants to Other Prefectures by Sex for Japan, Prefectures and 21 Major Cities (All nationalities and Japanese)
#
# 15
# Number of Intra-prefectural Migrants, In-migrants from Other Prefectures and Out-migrants to Other Prefectures by Sex for Japan, Prefectures and 19 Major Cities
#
# 16
# Number of Intra-prefectural Migrants, In-migrants from Other Prefectures and Out-migrants to Other Prefectures by Sex for Japan, Prefectures and 16 Major Cities
#
# 17
# Number of Inter-prefectural Migrants by Sex and Origin for Prefectures and 16 Major Cities
#
# 18
# Number of Inter-prefectural Migrants by Sex and Origin for Prefectures and 19 Major Cities
#
# 19
# Number of Intra-prefectural Migrants, In-migrants from Other Prefectures and Out-migrants to Other Prefectures by Sex for Japan, Prefectures, Tokyo Area, Nagoya Area, Osaka Area and 21 Major Cities (All nationalities and  Japanese)
#
#
#     count
# 0   55
# 1   55
# 2   54
# 3   47
# 4   42
# 5   41
# 6   41
# 7   41
# 8   28
# 9   27
# 10  27
# 11  24
# 12  24
# 13  15
# 14  13
# 15  12
# 16  12
# 17  12
# 18  9
# 19  6

# %% [markdown]
# The first excel workbook with the matching description is assigned as the sample workbook
